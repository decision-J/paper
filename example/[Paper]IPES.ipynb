# %% [markdown]
# # ES 구현하기
# ## until 01.22
#
# ### animated3 구현 완료. 논문 리뷰하면서 simul등 구현해보기

# %% [markdown]
# -------
# ## Animated3 구현 by IPES method

# %%
from __future__ import division
from __future__ import absolute_import
from __future__ import print_function

# %matplotlib inline

import time
start = time.time()

"""
Animated demo showing progress of Bayesian optimization on a simple
(but highly multimodal) one-dimensional function.
"""

import numpy as np
import reggie as rg
from reggie import models
from matplotlib import pyplot as ez

from pybo.bayesopt import IndexPolicy, RecPolicy
from pybo.domains import Grid

__all__ = []


def f(x):
    """
    Test function we'll optimize. This is a 1d, sinusoidal function used by
    Gramacy and Lee in "Cases for the nugget in modeling computer experiments".
    """
    x = float(x)
    return -np.sin(10*np.pi*x) / (2*x) - (x-1)**4


# define the bounds over which we'll optimize, the optimal x for
# comparison, and a sequence of test points
bounds = [0.5, 2.5]
xopt = 0.54856343
fopt = f(xopt)

# create the domain and the policies
domain = Grid(bounds, 100)

# policy choices: PI, EI, UCB, Thompson, PES, IPES
policy_name = 'IPES'

if policy_name == 'PES':
    policy = IndexPolicy(domain, 'PES', {'opes': False, 'ipes': False})
elif policy_name == 'IPES':
    policy = IndexPolicy(domain, 'PES', {'opes': False, 'ipes': True})
else:
    policy = IndexPolicy(domain, policy_name)

recommender = RecPolicy(domain, 'observed')

# get initial data and some test points.
def init(self, method='latin', rng=None, **kwargs):
        return continuous.INITS[method](self.bounds, rng=rng, **kwargs)
    
X = list(domain.init())
Y = [f(x_) for x_ in X]
F = []

# initialize the model
model = models.make_gp(0.01, 1.9, 0.1, 0)

# set the priors and make the model sample over hyperparameters
model.params['like']['sn2'].prior = rg.core.priors.Uniform(0.005, 0.015)
model.params['kern']['rho'].prior = rg.core.priors.LogNormal(0, 100)
model.params['kern']['ell'].prior = rg.core.priors.LogNormal(0, 10)
model.params['mean']['bias'].prior = rg.core.priors.Normal(0, 20)

# make a meta-model to sample over models; add data
model = models.MCMC(model, n=20, skip=True)
model.add_data(X, Y)

# grab a figure
fig = ez.figure()

n_iters = 30
for i in range(n_iters):
    print('Iteration: ' + str(i))
    # get the recommendation and the next query
    xbest = recommender(model, X, Y)
    xnext = policy(model, X)
    ynext = f(xnext)

    # evaluate the posterior before updating the model for plotting
    mu, s2 = model.predict(domain.X)

    # record our data and update the model
    X.append(xnext)
    Y.append(ynext)
    F.append(f(xbest))
    model.add_data(xnext, ynext)

    # PLOT EVERYTHING
    fig.clear()
    ax1 = ez.subplot2grid((2, 2), (0, 0))
    ax2 = ez.subplot2grid((2, 2), (1, 0), sharex=ax1)
    ax3 = ez.subplot2grid((2, 2), (0, 1), rowspan=2)
    ax1.get_xaxis().set_visible(False)

    # plot the posterior and data
    ax1.fill_between(domain.X.ravel(), mu + (2*np.sqrt(s2)), mu - (2*np.sqrt(s2)), alpha=0.5)
    ax1.scatter(np.ravel(X), Y)
    ax1.axvline(xbest, color='r')
    ax1.axvline(xnext, color='g')
    ax1.set_ylim(-6, 3)
    ax1.set_title('current model (xbest and xnext)')

    # plot the acquisition function
    ax2.fill_between(domain.X.ravel(), policy._index(domain.X), alpha=0.5)
    ax2.axvline(xnext, color='g')
    ax2.set_xlim(*bounds)
    ax2.set_title('current policy (xnext)')

    # plot the latent function at recomended points
    ax3.plot(F)
    ax3.axhline(fopt)
    ax3.set_ylim(0.4, 0.9)
    ax3.set_title('value of recommendation')

    # draw
    fig.canvas.draw()
    ez.show(block=False)

print("Running time :", time.time() - start, "sec")  # 실행 시간
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-1-6ed31dbbef40> in <module>
#      14
#      15 import numpy as np
# ---> 16 import reggie as rg
#      17 from reggie import models
#      18 from matplotlib import pyplot as ez
#
# ~\Anaconda3\lib\site-packages\reggie\__init__.py in <module>
#       5 # pylint: disable=wildcard-import
#       6
# ----> 7 from .models import *
#       8
#       9 from . import models
#
# ~\Anaconda3\lib\site-packages\reggie\models\__init__.py in <module>
#       5 # pylint: disable=wildcard-import
#       6
# ----> 7 from .gp import *
#       8 from .bandit import *
#       9 from .meta import *
#
# ~\Anaconda3\lib\site-packages\reggie\models\gp\__init__.py in <module>
#       5 # pylint: disable=wildcard-import
#       6
# ----> 7 from .gp import *
#       8 from .boot_gp import *
#       9 from .gp_light import *
#
# ~\Anaconda3\lib\site-packages\reggie\models\gp\gp.py in <module>
#      12
#      13 from ...utils.misc import rstate
# ---> 14 from ...utils import linalg as la
#      15
#      16 from ... import likelihoods
#
# ~\Anaconda3\lib\site-packages\reggie\utils\linalg.py in <module>
#      10 import warnings
#      11
# ---> 12 from scipy.linalg import lapack
#      13 from scipy.linalg import LinAlgError
#      14 from numpy.lib.stride_tricks import as_strided
#
# ModuleNotFoundError: No module named 'scipy.linalg'

# %% [markdown]
# ## Animated3 구현 by PES method

# %%
from __future__ import division
from __future__ import absolute_import
from __future__ import print_function

# %matplotlib inline

import time
start = time.time()

"""
Animated demo showing progress of Bayesian optimization on a simple
(but highly multimodal) one-dimensional function.
"""

import numpy as np
import reggie as rg
from matplotlib import pyplot as ez

from pybo.bayesopt import IndexPolicy, RecPolicy
from pybo.domains import Grid

__all__ = []


def f(x):
    """
    Test function we'll optimize. This is a 1d, sinusoidal function used by
    Gramacy and Lee in "Cases for the nugget in modeling computer experiments".
    """
    x = float(x)
    return -np.sin(10*np.pi*x) / (2*x) - (x-1)**4


# define the bounds over which we'll optimize, the optimal x for
# comparison, and a sequence of test points
bounds = [0.5, 2.5]
xopt = 0.54856343
fopt = f(xopt)

# create the domain and the policies
domain = Grid(bounds, 100)

# policy choices: PI, EI, UCB, Thompson, PES, IPES
policy_name = 'PES'

if policy_name == 'PES':
    policy = IndexPolicy(domain, 'PES', {'opes': False, 'ipes': False})
elif policy_name == 'IPES':
    policy = IndexPolicy(domain, 'PES', {'opes': False, 'ipes': True})
else:
    policy = IndexPolicy(domain, policy_name)

recommender = RecPolicy(domain, 'observed')

# get initial data and some test points.
def init(self, method='latin', rng=None, **kwargs):
        return continuous.INITS[method](self.bounds, rng=rng, **kwargs)
    
X = list(domain.init())
Y = [f(x_) for x_ in X]
F = []

# initialize the model
model = rg.make_gp(0.01, 1.9, 0.1, 0)

# set the priors and make the model sample over hyperparameters
model.params['like']['sn2'].prior = rg.priors.Uniform(0.005, 0.015)
model.params['kern']['rho'].prior = rg.priors.LogNormal(0, 100)
model.params['kern']['ell'].prior = rg.priors.LogNormal(0, 10)
model.params['mean']['bias'].prior = rg.priors.Normal(0, 20)

# make a meta-model to sample over models; add data
model = rg.MCMC(model, n=20, skip=True)
model.add_data(X, Y)

# grab a figure
fig = ez.figure()

n_iters = 30
for i in range(n_iters):
    print('Iteration: ' + str(i))
    # get the recommendation and the next query
    xbest = recommender(model, X, Y)
    xnext = policy(model, X)
    ynext = f(xnext)

    # evaluate the posterior before updating the model for plotting
    mu, s2 = model.predict(domain.X)

    # record our data and update the model
    X.append(xnext)
    Y.append(ynext)
    F.append(f(xbest))
    model.add_data(xnext, ynext)

    # PLOT EVERYTHING
    fig.clear()
    ax1 = ez.subplot2grid((2, 2), (0, 0))
    ax2 = ez.subplot2grid((2, 2), (1, 0), sharex=ax1)
    ax3 = ez.subplot2grid((2, 2), (0, 1), rowspan=2)
    ax1.get_xaxis().set_visible(False)

    # plot the posterior and data
    ax1.fill_between(domain.X.ravel(), mu + (2*np.sqrt(s2)), mu - (2*np.sqrt(s2)), alpha=0.5)
    ax1.scatter(np.ravel(X), Y)
    ax1.axvline(xbest, color='r')
    ax1.axvline(xnext, color='g')
    ax1.set_ylim(-6, 3)
    ax1.set_title('current model (xbest and xnext)')

    # plot the acquisition function
    ax2.fill_between(domain.X.ravel(), policy._index(domain.X), alpha=0.5)
    ax2.axvline(xnext, color='g')
    ax2.set_xlim(*bounds)
    ax2.set_title('current policy (xnext)')

    # plot the latent function at recomended points
    ax3.plot(F)
    ax3.axhline(fopt)
    ax3.set_ylim(0.4, 0.9)
    ax3.set_title('value of recommendation')

    # draw
    fig.canvas.draw()
    ez.show(block=False)

print("Running time :", time.time() - start, "sec")  # 실행 시간
# Out:
# C:\Users\letsd\Anaconda3\lib\site-packages\pybo\domains\domains.py:96: FutureWarning: arrays to stack must be passed as a "sequence" type such as list or tuple. Support for non-sequence iterables such as generators is deprecated as of NumPy 1.16 and will raise an error in the future.
#   for (a, b) in bounds])).T
# Iteration: 0
# Iteration: 1
# Iteration: 2
# Iteration: 3
# Iteration: 4
# Iteration: 5
# Iteration: 6
# Iteration: 7
# Iteration: 8
# Iteration: 9
# Iteration: 10
# Iteration: 11
# Iteration: 12
# Iteration: 13
# Iteration: 14
# Iteration: 15
# Iteration: 16
# Iteration: 17
# Iteration: 18
# Iteration: 19
# Iteration: 20
# Iteration: 21
# Iteration: 22
# Iteration: 23
# Iteration: 24
# Iteration: 25
# Iteration: 26
# Iteration: 27
# Iteration: 28
# Iteration: 29
# Running time : 36.85000014305115 sec

# %% [markdown]
# ## Animated3 구현 by EI method

# %%
from __future__ import division
from __future__ import absolute_import
from __future__ import print_function

# %matplotlib inline

import time
start = time.time()

"""
Animated demo showing progress of Bayesian optimization on a simple
(but highly multimodal) one-dimensional function.
"""

import numpy as np
import reggie as rg
from matplotlib import pyplot as ez

from pybo.bayesopt import IndexPolicy, RecPolicy
from pybo.domains import Grid

__all__ = []


def f(x):
    """
    Test function we'll optimize. This is a 1d, sinusoidal function used by
    Gramacy and Lee in "Cases for the nugget in modeling computer experiments".
    """
    x = float(x)
    return -np.sin(10*np.pi*x) / (2*x) - (x-1)**4


# define the bounds over which we'll optimize, the optimal x for
# comparison, and a sequence of test points
bounds = [0.5, 2.5]
xopt = 0.54856343
fopt = f(xopt)

# create the domain and the policies
domain = Grid(bounds, 100)

# policy choices: PI, EI, UCB, Thompson, PES, IPES
policy_name = 'EI'

if policy_name == 'PES':
    policy = IndexPolicy(domain, 'PES', {'opes': False, 'ipes': False})
elif policy_name == 'IPES':
    policy = IndexPolicy(domain, 'PES', {'opes': False, 'ipes': True})
else:
    policy = IndexPolicy(domain, policy_name)

recommender = RecPolicy(domain, 'observed')

# get initial data and some test points.
def init(self, method='latin', rng=None, **kwargs):
        return continuous.INITS[method](self.bounds, rng=rng, **kwargs)
    
X = list(domain.init())
Y = [f(x_) for x_ in X]
F = []

# initialize the model
model = rg.make_gp(0.01, 1.9, 0.1, 0)

# set the priors and make the model sample over hyperparameters
model.params['like']['sn2'].prior = rg.priors.Uniform(0.005, 0.015)
model.params['kern']['rho'].prior = rg.priors.LogNormal(0, 100)
model.params['kern']['ell'].prior = rg.priors.LogNormal(0, 10)
model.params['mean']['bias'].prior = rg.priors.Normal(0, 20)

# make a meta-model to sample over models; add data
model = rg.MCMC(model, n=20, skip=True)
model.add_data(X, Y)

# grab a figure
fig = ez.figure()

n_iters = 30
for i in range(n_iters):
    print('Iteration: ' + str(i))
    # get the recommendation and the next query
    xbest = recommender(model, X, Y)
    xnext = policy(model, X)
    ynext = f(xnext)

    # evaluate the posterior before updating the model for plotting
    mu, s2 = model.predict(domain.X)

    # record our data and update the model
    X.append(xnext)
    Y.append(ynext)
    F.append(f(xbest))
    model.add_data(xnext, ynext)

    # PLOT EVERYTHING
    fig.clear()
    ax1 = ez.subplot2grid((2, 2), (0, 0))
    ax2 = ez.subplot2grid((2, 2), (1, 0), sharex=ax1)
    ax3 = ez.subplot2grid((2, 2), (0, 1), rowspan=2)
    ax1.get_xaxis().set_visible(False)

    # plot the posterior and data
    ax1.fill_between(domain.X.ravel(), mu + (2*np.sqrt(s2)), mu - (2*np.sqrt(s2)), alpha=0.5)
    ax1.scatter(np.ravel(X), Y)
    ax1.axvline(xbest, color='r')
    ax1.axvline(xnext, color='g')
    ax1.set_ylim(-6, 3)
    ax1.set_title('current model (xbest and xnext)')

    # plot the acquisition function
    ax2.fill_between(domain.X.ravel(), policy._index(domain.X), alpha=0.5)
    ax2.axvline(xnext, color='g')
    ax2.set_xlim(*bounds)
    ax2.set_title('current policy (xnext)')

    # plot the latent function at recomended points
    ax3.plot(F)
    ax3.axhline(fopt)
    ax3.set_ylim(0.4, 0.9)
    ax3.set_title('value of recommendation')

    # draw
    fig.canvas.draw()
    ez.show(block=False)

print("Running time :", time.time() - start, "sec")  # 실행 시간
# Out:
# C:\Users\letsd\Anaconda3\lib\site-packages\pybo\domains\domains.py:96: FutureWarning: arrays to stack must be passed as a "sequence" type such as list or tuple. Support for non-sequence iterables such as generators is deprecated as of NumPy 1.16 and will raise an error in the future.
#   for (a, b) in bounds])).T
# Iteration: 0
# Iteration: 1
# Iteration: 2
# Iteration: 3
# Iteration: 4
# Iteration: 5
# Iteration: 6
# Iteration: 7
# Iteration: 8
# Iteration: 9
# Iteration: 10
# Iteration: 11
# Iteration: 12
# Iteration: 13
# Iteration: 14
# Iteration: 15
# Iteration: 16
# Iteration: 17
# Iteration: 18
# Iteration: 19
# Iteration: 20
# Iteration: 21
# Iteration: 22
# Iteration: 23
# Iteration: 24
# Iteration: 25
# Iteration: 26
# Iteration: 27
# Iteration: 28
# Iteration: 29
# Running time : 28.47290539741516 sec
